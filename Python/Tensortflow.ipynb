# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
import numpy as np

# %%
def get_y(x):
    return 4 * x + 7

# %%
x = np.random.randint(-100, 100, 500)
print(x)
y = get_y(x)
y.shape

# -100에서 100 사이의 정수 중 500개를 랜덤하게 생성하여 x라는 변수에 저장합니다. 이로 인해 x는 500개의 정수로 이루어진 NumPy 배열이 됩니다.
# Out:
# [  65   73   35  -77   39   -8   -2   24   35  -95   34   22  -11   76
#    41   11  -50   39    3   61   89   96    3   34   20  -18  -76   98
#   -87  -46   52  -36   36   42  -87   41   14  -93   21  -90   20    8
#    15   21  -79  -54  -64  -74   94  -68  -20  -96   -2   72  -51   52
#    28  -42   65   89  -20  -20   61   57  -10  -98  -64    2   70   47
#    12    9  -32   38   12  -26  -56  -10   13   56   16 -100   54  -24
#   -77  -98   70   37  -94  -15  -35  -25  -63    0   67  -29  -89    6
#    96   93  -34  -37   42   90   15 -100  -59  -86  -92  -58   54   88
#    -3  -81   -2   96   57   16  -28   78  -56   72   79   99   93  -79
#     9   22  -95  -15  -16  -37  -95  -96   91   52  -36   28  -40  -42
#    -7   37   46  -27   66   74   89   45   -2   52   49   77   22   24
#   -20  -72   57   97   41   95   50   12   19  -91  -15  -39  -33   34
#    82   93   48  -12  -42  -12    0  -25   16   53  -44   38  -17  -71
#    83  -31  -94   -1   31   76  -47  -77  -88   80  -59  -71   58   22
#   -76  -65   94   62  -87    1   10   70   14   12   25   40   87   74
#    54   69  -28  -17  -33  -32   25  -38  -26   26   51  -56   43  -33
#   -92  -49  -90   75  -51  -10   -6   69  -14  -22  -41   72   -4   11
#   -35  -86  -97  -14   36  -32    5  -32   24  -18   72  -15  -77   21
#    -2   73    4   44  -84  -63  -69  -97  -36   52   51   90   81  -29
#     8   37  -79   65  -60   56    1   12   43   71  -62   20   98  -17
#   -36   16   46  -93   63   99   97  -89  -97   -3   65   61  -49  -19
#    66    3   -3  -33   20  -58   27  -38 -100   70   90   76   -2   59
#    26   89  -36    0   79   -8  -46   90    8   27   18   78   39   79
#   -36  -52  -68   61  -82   -5   49  -82  -14   16  -18 -100  -84   15
#   -74  -73   22  -33  -43   99   79    1  -32  -69  -59   92 -100   57
#   -43  -23  -97   90  -97   34  -90  -29  -14   66   62  -67  -37  -81
#    23   39   -8   89    9   88   43   -2  -63  -11  -72    7  -63   87
#   -46  -30    8   91   -5   34   79    3  -28  -28  -60   89   84   71
#   -32   53   51  -74   -5   94   42  -36   99    3   12  -94   39   96
#   -24   87  -86   51  -39  -96  -72  -60  -13   71   51   21   23  -75
#     3   32   50  -82   22   69   40  -33   90  -63  -50  -25   27  -97
#     7  -93  -98   91   99    6    3  -70  -91  -62   59   56  -19  -86
#    71  -19   18  -78   -6   52  -47   38   88   70  -67   -6  -91   77
#    69   99   49  -61   64   94   -9   49  -51  -14  -14  -11   49   29
#    22  -60   -6  -24   98  -30   -4   44  -24  -54   41  -12  -45   44
#    64   15   71   89  -58   10  -68    3   93    0]
# (500,)

# %%
X= x.reshape(-1,1) # 500행 1열 , X는 500행 1열의 2차원 배열로 재구성됩니다.

# %%
X.shape
# Out:
# (500, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=0)
'''
est_size=.2: 전체 데이터 중에서 20%를 테스트 세트로 사용하겠다는 의미입니다. 나머지 80%는 훈련 세트로 사용됩니다.
random_state=0: 난수 생성의 시드를 설정하여 결과의 재현성을 보장합니다. 동일한 random_state 값을 사용하면 매번 동일한 방식으로 데이터가 분리됩니다.



훈련 세트는 모델이 학습하는 데 사용되며, 모델의 가중치와 파라미터를 조정합니다.
테스트 세트는 모델의 성능을 평가하는 데 사용되며, 모델이 실제로 새로운 데이터에 대해 얼마나 잘 작동하는지를 확인합니다.

'''

# %%
# X : 문제 , y: 정답

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

'''

입력 파라미터:

X: 입력 데이터(특성)입니다. 여기서는 2차원 배열로, 500개의 샘플과 1개의 특성을 가진 배열입니다.
y: 타겟 데이터(정답)입니다. 여기서는 get_y(x) 함수에 의해 생성된 출력 배열입니다.
test_size=.2: 전체 데이터 중에서 20%를 테스트 세트로 사용하겠다는 의미입니다. 나머지 80%는 훈련 세트로 사용됩니다.
random_state=0: 난수 생성의 시드를 설정하여 결과의 재현성을 보장합니다. 동일한 random_state 값을 사용하면 매번 동일한 방식으로 데이터가 분리됩니다.
결과:

X_train: 훈련 세트의 입력 데이터(80%).
X_test: 테스트 세트의 입력 데이터(20%).
y_train: 훈련 세트의 타겟 데이터(80%).
y_test: 테스트 세트의 타겟 데이터(20%).
'''
# Out:
# ((400, 1), (100, 1), (400,), (100,))

# %%
reg_model = Sequential()
#input_dim=1은 우리가 이 신경망에 하나의 숫자(입력)만 줄 거라는 뜻
reg_model.add( Dense(1, input_dim=1)) # Input Layer ,Fully Connected Layer
reg_model.add( Dense(128)) # Hidden Layer  10: 뉴런의 수
reg_model.add( Dense(64))
reg_model.add( Dense(31))
reg_model.add( Dense(16))
reg_model.add( Dense(1))  # Output Layer
# 1개의 뉴런을 가진 출력 층이에요.
# 신경망을 만듬
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
reg_model.summary() # 인공 신경망 요약
# Total params: 203 (812.00 B) 총 파라미터 가중치 +bias
#Trainable params: 203 (812.00 B) 학습을 위한 파라미터
#Non-trainable params: 0 (0.00 B)
# 가중치가 많을 수록 복잡한 문제를 풀 수있다
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 1)                   │               2 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 31)                  │           2,015 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 16)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,058 (43.20 KB)
#  Trainable params: 11,058 (43.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#가중치(Weight): 입력값에 곱해지는 수

# %%
reg_model.compile(loss='mse',optimizer="adam",metrics=['mse'])

#예측한 값과 실제 값의 차이를 계산해서 얼마나 잘 맞는지를 측정
#mse : 평균 제곱 오차
#옵티마이저: adam은 신경망을 학습할 때 가중치를 조정하는 방법이에요.
#평가 지표: metrics에 mse를 추가하는 것은 모델이 학습하는 동안 성능을 모니터링하기 위한 방법이에요.
#의미: 이렇게 설정하면 모델이 학습할 때마다 손실(MSE)을 기록하고, 학습이 얼마나 잘 되고 있는지를 볼 수 있어요.
'''
손실 함수 (Loss Function): 모델의 예측과 실제 값 간의 차이를 측정하는 함수입니다. 여기서 'mse'는 Mean Squared Error(평균 제곱 오차)를 의미합니다.

최적화 알고리즘 (Optimizer): 손실 함수를 최소화하기 위해 가중치를 조정하는 알고리즘입니다. 여기서는 Adam 옵티마이저를 사용하고 있습니다.
Adam은 경사 하강법을 기반으로 하며, 학습률을 자동으로 조정하여 빠르고 효율적인 학습을 지원

metrics=['mse']:평가지표 (Metrics): 모델의 성능을 평가하기 위해 사용할 지표입니다. 여기서 'mse'는 평균 제곱 오차를 의미하며, 훈련 및 검증 과정에서 모델의 성능을 모니터링하는 데 사용

'''
# Out:
# "\n손실 함수 (Loss Function): 모델의 예측과 실제 값 간의 차이를 측정하는 함수입니다. 여기서 'mse'는 Mean Squared Error(평균 제곱 오차)를 의미합니다.\n\n최적화 알고리즘 (Optimizer): 손실 함수를 최소화하기 위해 가중치를 조정하는 알고리즘입니다. 여기서는 Adam 옵티마이저를 사용하고 있습니다.\nAdam은 경사 하강법을 기반으로 하며, 학습률을 자동으로 조정하여 빠르고 효율적인 학습을 지원\n\nmetrics=['mse']:평가지표 (Metrics): 모델의 성능을 평가하기 위해 사용할 지표입니다. 여기서 'mse'는 평균 제곱 오차를 의미하며, 훈련 및 검증 과정에서 모델의 성능을 모니터링하는 데 사용\n\n"

# %%
hist=reg_model.fit(X_train,y_train,epochs=30,batch_size=10,validation_split=.1)

#epochs=100 : 학습의 횟수
#batch_size=10 : 데이터 10개를 전달하고 에러의 평균을 내서 가중치를 갱신하겠다는 의미
#이 설정은 전체 데이터의 **10%**를 검증 데이터로 사용하겠다는 뜻이에요. 즉, 훈련 데이터에서 90%는 모델을 학습하는
#왜 필요한가?:
'''
모델을 학습하는 동안 항상 같은 데이터를 사용하면, 모델이 그 데이터에 너무 익숙해져서 새로운 데이터에 대한 성능이 떨어질 수 있어요. 이를 **과적합(Overfitting)**이라고 해요.
검증 데이터를 사용하면 모델이 학습 중에 보지 못한 데이터로 성능을 평가할 수 있어요. 이렇게 하면 모델이 잘 학습하고 있는지를 확인할 수 있죠.

하이퍼파라미터의 특징

모델의 매개 변수를 추정하는 데 도움이 되는 프로세스에서 사용된다.
하이퍼파라미터는 개발자에 의해 수동으로 설정할 수 있다.(임의 조정 가능)
학습 알고리즘의 샘플에 대한 일반화를 위해 조절된다.

하이퍼파라미터의 예

학습률
손실 함수
일반화 파라미터
미니배치 크기
에포크 수
가중치 초기화
은닉층의 개수
k-NN의 k값

'''
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 39372.4883 - mse: 39372.4883 - val_loss: 1712.2092 - val_mse: 1712.2092
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1252.5327 - mse: 1252.5327 - val_loss: 0.4852 - val_mse: 0.4852
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.9377 - mse: 46.9377 - val_loss: 5.1347 - val_mse: 5.1347
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2115 - mse: 2.2115 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0373 - mse: 0.0373 - val_loss: 9.4109e-04 - val_mse: 9.4109e-04
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0566e-04 - mse: 7.0566e-04 - val_loss: 3.8137e-05 - val_mse: 3.8137e-05
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6882e-05 - mse: 1.6882e-05 - val_loss: 4.8781e-07 - val_mse: 4.8781e-07
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3282e-07 - mse: 3.3282e-07 - val_loss: 2.2511e-08 - val_mse: 2.2511e-08
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6020e-09 - mse: 9.6020e-09 - val_loss: 4.3997e-10 - val_mse: 4.3997e-10
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0305e-10 - mse: 3.0305e-10 - val_loss: 3.5257e-10 - val_mse: 3.5257e-10
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1278e-10 - mse: 3.1278e-10 - val_loss: 2.8086e-10 - val_mse: 2.8086e-10
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2703e-10 - mse: 2.2703e-10 - val_loss: 2.6053e-10 - val_mse: 2.6053e-10
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0392e-10 - mse: 2.0392e-10 - val_loss: 2.6790e-10 - val_mse: 2.6790e-10
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5989e-10 - mse: 2.5989e-10 - val_loss: 2.5516e-10 - val_mse: 2.5516e-10
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7862e-10 - mse: 2.7862e-10 - val_loss: 2.6499e-10 - val_mse: 2.6499e-10
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0484e-10 - mse: 3.0484e-10 - val_loss: 2.9118e-10 - val_mse: 2.9118e-10
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9447e-10 - mse: 2.9447e-10 - val_loss: 2.7703e-10 - val_mse: 2.7703e-10
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7073e-10 - mse: 2.7073e-10 - val_loss: 2.7667e-10 - val_mse: 2.7667e-10
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2196e-10 - mse: 2.2196e-10 - val_loss: 2.6362e-10 - val_mse: 2.6362e-10
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7896e-10 - mse: 1.7896e-10 - val_loss: 2.5798e-10 - val_mse: 2.5798e-10
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1733e-10 - mse: 2.1733e-10 - val_loss: 3.1525e-10 - val_mse: 3.1525e-10
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9353e-10 - mse: 2.9353e-10 - val_loss: 2.0591e-10 - val_mse: 2.0591e-10
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0562e-10 - mse: 2.0562e-10 - val_loss: 2.7321e-10 - val_mse: 2.7321e-10
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6512e-10 - mse: 1.6512e-10 - val_loss: 2.4993e-10 - val_mse: 2.4993e-10
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6500e-10 - mse: 1.6500e-10 - val_loss: 2.5575e-10 - val_mse: 2.5575e-10
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7285e-10 - mse: 1.7285e-10 - val_loss: 2.7342e-10 - val_mse: 2.7342e-10
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3574e-10 - mse: 1.3574e-10 - val_loss: 2.6157e-10 - val_mse: 2.6157e-10
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7832e-10 - mse: 1.7832e-10 - val_loss: 2.5575e-10 - val_mse: 2.5575e-10
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7724e-10 - mse: 1.7724e-10 - val_loss: 2.4520e-10 - val_mse: 2.4520e-10
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8177e-10 - mse: 2.8177e-10 - val_loss: 3.8781e-10 - val_mse: 3.8781e-10
# '\n하이퍼파라미터의 특징\n\n모델의 매개 변수를 추정하는 데 도움이 되는 프로세스에서 사용된다.\n하이퍼파라미터는 개발자에 의해 수동으로 설정할 수 있다.(임의 조정 가능)\n학습 알고리즘의 샘플에 대한 일반화를 위해 조절된다.\n\n하이퍼파라미터의 예\n\n학습률\n손실 함수\n일반화 파라미터\n미니배치 크기\n에포크 수\n가중치 초기화\n은닉층의 개수\nk-NN의 k값\n\n'

# %%
hist.history.keys() # 학습 내역의 손실,손실^2의 평균 ,
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
loss = hist.history['loss']
mse = hist.history['mse']
vloss = hist.history['val_loss']
vmae = hist.history['val_mse']
'''
검증 손실(val_loss):

vloss = hist.history['val_loss']는 검증 데이터에서의 손실 값을 가져오는 코드예요.
의미: 손실 값은 모델이 예측한 값과 실제 값의 차이를 나타내며, 낮을수록 모델의 예측이 실제 값에 가깝다는 뜻이에요.
이렇게 가져온 검증 손실 값을 사용하여 모델의 성능을 평가할 수 있어요.
검증 평균 제곱 오차(val_mse):

vmae = hist.history['val_mse']는 검증 데이터에서의 평균 제곱 오차(MSE)를 가져오는 코드예요.
의미: MSE는 예측 값과 실제 값의 차이를 제곱하여 평균을 낸 값으로, 손실과 유사하지만 다른 형태의 지표예요. 역시 낮을수록 좋죠.

'''

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,2))
plt.plot(loss, 'r--', label='loss')  # r -- 빨간 -- 선
# plot : Line(선) 차트
plt.plot(mse, 'g', label='mse')
plt.plot(vloss, 'y--', label='val_loss')
plt.plot(vmae, 'b', label='val_mse')
plt.legend()
plt.show()

# %%
reg_model.evaluate(X_test,y_test) # 학습에 사용하지 않은 데이터
 # 2.0422931401586908e-10, 2.0422931401586908e-10
 #-10 왼쪽으로 10 0.000000~~~?
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3776e-10 - mse: 2.3776e-10
# [2.0422931401586908e-10, 2.0422931401586908e-10]

# %%
reg_model.predict(np.array([-50.0])),get_y(-50)
#reg_model.predict(np.array([-50.0]))는 신경망 모델을 #사용해 -50.0에 대한 예측 값을 반환

#get_y(-50)는 주어진 함수에 따라 -50에 대한 실제 값을 계산하여 반환합니다.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# (array([[-193.00002]], dtype=float32), -193)

# %% [markdown]
# # 1차 함수로 데이터를 생성하고 노이즈 결합하기

# %%
# y= 2x +5
# 1~10 사이의  테이터를 1000개 생성 x= np.linspace(1,10,1000)
# 노이즈 : np.random.normal(3,3.1000)
# y'= 2x+5 +noise  : 노이즈가 섞인 y 데이터
# Linear Regression , Tensorflow
# x= 15일때 의 y는?  35

# %%
x = np.linspace(1,10,1000)
print(x)
# Out:
# [ 1.          1.00900901  1.01801802  1.02702703  1.03603604  1.04504505
#   1.05405405  1.06306306  1.07207207  1.08108108  1.09009009  1.0990991
#   1.10810811  1.11711712  1.12612613  1.13513514  1.14414414  1.15315315
#   1.16216216  1.17117117  1.18018018  1.18918919  1.1981982   1.20720721
#   1.21621622  1.22522523  1.23423423  1.24324324  1.25225225  1.26126126
#   1.27027027  1.27927928  1.28828829  1.2972973   1.30630631  1.31531532
#   1.32432432  1.33333333  1.34234234  1.35135135  1.36036036  1.36936937
#   1.37837838  1.38738739  1.3963964   1.40540541  1.41441441  1.42342342
#   1.43243243  1.44144144  1.45045045  1.45945946  1.46846847  1.47747748
#   1.48648649  1.4954955   1.5045045   1.51351351  1.52252252  1.53153153
#   1.54054054  1.54954955  1.55855856  1.56756757  1.57657658  1.58558559
#   1.59459459  1.6036036   1.61261261  1.62162162  1.63063063  1.63963964
#   1.64864865  1.65765766  1.66666667  1.67567568  1.68468468  1.69369369
#   1.7027027   1.71171171  1.72072072  1.72972973  1.73873874  1.74774775
#   1.95686623e+00  3.34624954e+00  7.17628106e+00  4.93349559e-01]

# %%
def get_y2(x):
    return 2 * x + 5

# %%
x = np.linspace(1,10,1000)
noise = np.random.normal(3,3,1000) #평균이 3, 표준편차가 3인 노이즈 생성 정규 분포
y=get_y2(x)+ noise

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y ,s=1) # s 점의 크기
plt.show()
# 아래 그래프를 관통하는 직선을 가져오기

# %%
x.shape
# Out:
# (1000,)

# %%
X= x.reshape(-1,1)
X.shape ,y.shape
# Out:
# ((1000, 1), (1000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 1), (200, 1), (800,), (200,))

# %%
reg_model = Sequential()
reg_model.add( Dense(1, input_dim=1))
reg_model.add( Dense(20))
reg_model.add( Dense(1 ,activation='linear'))  #활성 함수

# %%
reg_model.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_83 (Dense)                     │ (None, 1)                   │               2 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_84 (Dense)                     │ (None, 20)                  │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_85 (Dense)                     │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63 (252.00 B)
#  Trainable params: 63 (252.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
reg_model.compile(loss='mse',optimizer="adam",metrics=['mse'])

# %%
hist=reg_model.fit(X_train,y_train,epochs=100,batch_size=10,validation_split=.1)
# Out:
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 360.1528 - mse: 360.1528 - val_loss: 228.2474 - val_mse: 228.2474
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 159.1411 - mse: 159.1411 - val_loss: 72.2849 - val_mse: 72.2849
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.2613 - mse: 47.2613 - val_loss: 20.7622 - val_mse: 20.7622
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3363 - mse: 20.3363 - val_loss: 15.5006 - val_mse: 15.5006
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7667 - mse: 14.7667 - val_loss: 15.0739 - val_mse: 15.0739
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.3736 - mse: 16.3736 - val_loss: 14.7604 - val_mse: 14.7604
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.8886 - mse: 15.8886 - val_loss: 14.5487 - val_mse: 14.5487
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6893 - mse: 15.6893 - val_loss: 14.2447 - val_mse: 14.2447
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8085 - mse: 13.8085 - val_loss: 14.0912 - val_mse: 14.0912
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7969 - mse: 14.7969 - val_loss: 13.6717 - val_mse: 13.6717
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.1687 - mse: 14.1687 - val_loss: 13.4077 - val_mse: 13.4077
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.4946 - mse: 13.4946 - val_loss: 13.1465 - val_mse: 13.1465
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.6490 - mse: 13.6490 - val_loss: 12.8607 - val_mse: 12.8607
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2262 - mse: 12.2262 - val_loss: 12.6154 - val_mse: 12.6154
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.9704 - mse: 11.9704 - val_loss: 12.5811 - val_mse: 12.5811
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1012 - mse: 13.1012 - val_loss: 12.0835 - val_mse: 12.0835
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.2408 - mse: 13.2408 - val_loss: 11.9344 - val_mse: 11.9344
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.8637 - mse: 11.8637 - val_loss: 11.7756 - val_mse: 11.7756
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.7075 - mse: 12.7075 - val_loss: 11.4928 - val_mse: 11.4928
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.5103 - mse: 11.5103 - val_loss: 11.0870 - val_mse: 11.0870
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2156 - mse: 12.2156 - val_loss: 11.0034 - val_mse: 11.0034
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.9843 - mse: 11.9843 - val_loss: 10.9107 - val_mse: 10.9107
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.3819 - mse: 11.3819 - val_loss: 10.5035 - val_mse: 10.5035
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.6520 - mse: 10.6520 - val_loss: 10.5354 - val_mse: 10.5354
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.2564 - mse: 11.2564 - val_loss: 10.5528 - val_mse: 10.5528
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2564 - mse: 9.2564 - val_loss: 8.5220 - val_mse: 8.5220
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5692 - mse: 9.5692 - val_loss: 8.2124 - val_mse: 8.2124
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1990 - mse: 8.1990 - val_loss: 8.1033 - val_mse: 8.1033
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8709 - mse: 8.8709 - val_loss: 8.0773 - val_mse: 8.0773
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1404 - mse: 9.1404 - val_loss: 8.6479 - val_mse: 8.6479
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1329 - mse: 9.1329 - val_loss: 8.0408 - val_mse: 8.0408
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9554 - mse: 8.9554 - val_loss: 8.0975 - val_mse: 8.0975
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6192 - mse: 8.6192 - val_loss: 8.6223 - val_mse: 8.6223
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9558 - mse: 8.9558 - val_loss: 8.7249 - val_mse: 8.7249
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2079 - mse: 9.2079 - val_loss: 8.8983 - val_mse: 8.8983
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0352 - mse: 9.0352 - val_loss: 8.4069 - val_mse: 8.4069
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5127 - mse: 9.5127 - val_loss: 8.7283 - val_mse: 8.7283
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1167 - mse: 9.1167 - val_loss: 9.0454 - val_mse: 9.0454
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5761 - mse: 9.5761 - val_loss: 8.8055 - val_mse: 8.8055
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1296 - mse: 8.1296 - val_loss: 8.0593 - val_mse: 8.0593
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2322 - mse: 9.2322 - val_loss: 8.1589 - val_mse: 8.1589
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7101 - mse: 9.7101 - val_loss: 8.0737 - val_mse: 8.0737
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4568 - mse: 9.4568 - val_loss: 8.1255 - val_mse: 8.1255
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7525 - mse: 8.7525 - val_loss: 8.2293 - val_mse: 8.2293
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9843 - mse: 8.9843 - val_loss: 8.5353 - val_mse: 8.5353
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8864 - mse: 9.8864 - val_loss: 8.0743 - val_mse: 8.0743
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4312 - mse: 9.4312 - val_loss: 9.1669 - val_mse: 9.1669
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4283 - mse: 9.4283 - val_loss: 8.1341 - val_mse: 8.1341
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1892 - mse: 9.1892 - val_loss: 8.5648 - val_mse: 8.5648
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9930 - mse: 8.9930 - val_loss: 8.8976 - val_mse: 8.8976
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9918 - mse: 8.9918 - val_loss: 8.2472 - val_mse: 8.2472
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0068 - mse: 9.0068 - val_loss: 9.1009 - val_mse: 9.1009
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2342 - mse: 9.2342 - val_loss: 8.2938 - val_mse: 8.2938
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8813 - mse: 8.8813 - val_loss: 8.1614 - val_mse: 8.1614
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4730 - mse: 8.4730 - val_loss: 8.1257 - val_mse: 8.1257
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1237 - mse: 9.1237 - val_loss: 8.5745 - val_mse: 8.5745
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9406 - mse: 8.9406 - val_loss: 8.1419 - val_mse: 8.1419
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4740 - mse: 9.4740 - val_loss: 8.1536 - val_mse: 8.1536
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5205 - mse: 9.5205 - val_loss: 8.8557 - val_mse: 8.8557

# %%
loss = hist.history['loss']
mse = hist.history['mse']
vloss = hist.history['val_loss']
vmae = hist.history['val_mse']
'''
lose= 훈련 데이터에 대한 손실 값입니다. 모델이 훈련 과정에서 얼마나 잘 학습했는지를 나타냅니다.

해석:lose, mes(평균제곱 오차),이 값이 작을수록 모델이 훈련 데이터에 잘 적합하고 있다는 것을 의미합니다. 즉, 예측값과 실제값 간의 차이가 적다는 것입니다.

vloss =검증 데이터에 대한 손실 값입니다. 모델이 검증 데이터에 대해 얼마나 잘 예측하는지를 평가합니다.
해석: vloss,vmae이 값이 낮을수록 모델이 검증 데이터에 대해 잘 적합하고 있다는 것을 의미합니다. 훈련 데이터에 비해 검증 데이터의 손실 값이 높으면 과적합(overfitting) 가능성을 나타낼 수 있습니다.



'''
# Out:
# '\nlose= 훈련 데이터에 대한 손실 값입니다. 모델이 훈련 과정에서 얼마나 잘 학습했는지를 나타냅니다.\n\n해석:lose, mes(평균제곱 오차),이 값이 작을수록 모델이 훈련 데이터에 잘 적합하고 있다는 것을 의미합니다. 즉, 예측값과 실제값 간의 차이가 적다는 것입니다.\n\nvloss =검증 데이터에 대한 손실 값입니다. 모델이 검증 데이터에 대해 얼마나 잘 예측하는지를 평가합니다.\n해석: vloss,vmae이 값이 낮을수록 모델이 검증 데이터에 대해 잘 적합하고 있다는 것을 의미합니다. 훈련 데이터에 비해 검증 데이터의 손실 값이 높으면 과적합(overfitting) 가능성을 나타낼 수 있습니다.\n\n\n\n'

# %%
plt.figure(figsize=(5,2))
plt.plot(loss, 'r--', label='loss')  # r -- 빨간 -- 선
# plot : Line(선) 차트
plt.plot(mse, 'g', label='mse')
plt.plot(vloss, 'y--', label='val_loss')
plt.plot(vmae, 'b', label='val_mse')
plt.legend()
plt.show()

# %%
reg_model.evaluate(X_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8957 - mse: 7.8957
# [8.192462921142578, 8.192462921142578]

# %%
reg_model.predict(np.array([15])),get_y2(15)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# (array([[37.120834]], dtype=float32), 35)

# %% [markdown]
# ## 다중변수 함수의 값 회귀 분석
# * y= 3x1+ 5x2 + 7 + noise
#
# * x1: 500 개
# * x2 :500 개
# * x1.y 산점도 표시
# * x2. y 산점도 표시
# * input_dim =2
# X.shape -> (500,2)
# [[x1,x2],[x1,x2]...]

# %%
x1=np.random.randint(1,100,500)
x2=np.random.randint(1,100,500)

# %%
y=3 * x1 + 5 * x2 +7 + np.random.normal(0,3,500)

# %%
import matplotlib.pyplot as plt

plt.scatter(x1,y,s=1,label='x1',c='r')
plt.scatter(x2,y,s=1,label='x2',c='g')
plt.legend()
plt.show()

# %%
X= np.array([x1,x2]).T # 2열의 2차원 배열이됨
X.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-209-1f567dcd0c8a> in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=0)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2780         raise ValueError("At least one array required as input")
#    2781
# -> 2782     arrays = indexable(*arrays)
#    2783
#    2784     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     512
#     513     result = [_make_indexable(X) for X in iterables]
# --> 514     check_consistent_length(*result)
#     515     return result
#     516
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     455     uniques = np.unique(lengths)
#     456     if len(uniques) > 1:
# --> 457         raise ValueError(
#     458             "Found input variables with inconsistent numbers of samples: %r"
#     459             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1000, 500]

# %%
model=Sequential()
model.add( Dense(2, input_dim=2))
model.add( Dense(64))
model.add( Dense(32))
model.add( Dense(16))
model.add( Dense(8))
model.add( Dense(4))
model.add( Dense(2))
model.add( Dense(1 ,activation='linear'))  #활성 함수

# %%
model.compile(loss='mse',optimizer="adam",metrics=['mse'])

# %%
hist=model.fit(X_train,y_train,epochs=500,batch_size=10,validation_split=.1)
